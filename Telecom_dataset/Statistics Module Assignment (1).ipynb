# %% [markdown]
# <a id='1'></a><center> <h3 style="background-color:orange; color:white" ><br>Telecommunication Industry Project<br></h3>

# %% [markdown]
# # Introduction
# This Jupyter notebook is part of your learning experience in the study of applied statistics.
#
# You will work with a data set that contains mobile phone prices and their specifications.
#
# **Dataset Columns Information**
#
# PID = a unique identifier for the phone model
#
# Blue = whether the phone has bluetooth support or not
#
# Wi_Fi = whether the phone has wifi support or not
#
# Tch_Scr = whether the phone has touch screen support or not
#
# Ext_Mem = whether the phone has external memory support or not
#
# Px_h = number of pixels in the vertical axis of the phone
#
# Px_w = number of pixels in the horizontal axis of the phone
#
# Scr_h = height of the screen of the phone in centimetres (cm)
#
# Scr_w = width of the screen of the phone in centimetres (cm)
#
# Int_Mem = internal memory of the phone measured in megabytes (MB)
#
# Bty_Pwr = maximum energy stored by the phone's battery measured in
# milli-Ampere-hours (mAh)
#
# PC = resolution of the primary camera measued in megapixels (MP)
#
# FC = resolution of the front camera measued in megapixels (MP)
#
# RAM = random access memory available in the phone measured in gigabytes (GB)
#
# Depth = depth of the mobile phone measured in centimetres (cm)
#
# Weight = weight of the mobile phone measured in grams (g)
#
# Price = selling price of the mobile phone in rupees

# %% [markdown]
# ## Task 1 - Load and study the data

# %% [markdown]
# Import the libraries that will be used in this notebook

# %%
# Load "numpy" and "pandas" for manipulating numbers and data frames
# Load "matplotlib.pyplot" and "seaborn" for data visualisation

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Load the csv file as pandas dataframe.

# %%
# Read in the "Dataset" file as a Pandas Data Frame
df=pd.read_csv("Telecom Dataset.csv")

# %%
# Take a brief look at the data
df.head()
# Out:
#        PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  FC  \
# 0  AAB346A  yes   yes      no      no   780   460      3      1   2   2
# 1  AAC347I  yes   yes      no      no   780   560      2      1   4   2
# 2  BAB657J   no   yes      no      no   840   720      2      1   4   2
# 3  BBD456K   no   yes     yes      no  1280  1120      5      3   6   2
# 4  CCP761U   no   yes     yes      no  1280  1080      4      3   6   2
#
#    Int_Mem  Bty_Pwr  RAM  Depth  Weight  Price
# 0        8     2800    2      7     320   3297
# 1        8     3000    2      7     280   4500
# 2        8     3300    2      7     400   4898
# 3       32     3000    2      3     300   6900
# 4       16     3000    2      3     210   5600

# %%
# Get the dimensions of the dataframe

df.shape
# Out:
# (50, 17)

# %%
# Get the row names of the dataframe

row_names = df.index
print("Row names (index values):")
print(row_names)
# Out:
# Row names (index values):
# RangeIndex(start=0, stop=50, step=1)

# %%
# Get the column names of the dataframe
df.columns
# Out:
# Index(['PID', 'Blue', 'Wi_Fi', 'Tch_Scr', 'Ext_Mem', 'Px_h', 'Px_w', 'Scr_h',
#        'Scr_w', 'PC', 'FC', 'Int_Mem', 'Bty_Pwr', 'RAM', 'Depth', 'Weight',
#        'Price'],
#       dtype='object')

# %%
# Look at basic information about the dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PID      50 non-null     object
#  1   Blue     50 non-null     object
#  2   Wi_Fi    50 non-null     object
#  3   Tch_Scr  50 non-null     object
#  4   Ext_Mem  50 non-null     object
#  5   Px_h     50 non-null     int64
#  6   Px_w     50 non-null     int64
#  7   Scr_h    50 non-null     int64
#  8   Scr_w    50 non-null     int64
#  9   PC       50 non-null     int64
#  10  FC       50 non-null     int64
#  11  Int_Mem  50 non-null     int64
#  12  Bty_Pwr  50 non-null     int64
#  13  RAM      50 non-null     int64
#  14  Depth    50 non-null     int64
#  15  Weight   50 non-null     int64
#  16  Price    50 non-null     int64
# dtypes: int64(12), object(5)
# memory usage: 6.8+ KB

# %% [markdown]
# Observations:
#
# There are 50 phones in the data set.
#
# There are 17 features in the data set including the "PID" feature which is used as the row index labels.
#
# There are no missing values in the data set.

# %% [markdown]
# <center>Let's try some logical operators to filter the data.<center>

# %% [markdown]
# ![](https://th.bing.com/th/id/R.0592084daa6518e4fae97f47217ec69e?rik=vNqmiaTVSSo54w&riu=http%3a%2f%2f2.bp.blogspot.com%2f-ujABms6N-Cg%2fTyYwShdTjnI%2fAAAAAAAAAAs%2fktPbHdifidc%2fs1600%2fLogical%2bOperators.PNG&ehk=ww1gl1HB2PcZwPQNHWRUvcQ631Q3mzyHSxL9G4zUKT4%3d&risl=&pid=ImgRaw&r=0,width=700,height=400)

# %% [markdown]
# ## Task 2 - Obtain the logical conditions for the features "Blue", "Wi_Fi", "Tch_Scr" and "Ext_Mem"

# %%
# Get the feature names of the dataframe

feature_names = df.columns
print("Feature names (column names):")
print(feature_names)
# Out:
# Feature names (column names):
# Index(['PID', 'Blue', 'Wi_Fi', 'Tch_Scr', 'Ext_Mem', 'Px_h', 'Px_w', 'Scr_h',
#        'Scr_w', 'PC', 'FC', 'Int_Mem', 'Bty_Pwr', 'RAM', 'Depth', 'Weight',
#        'Price'],
#       dtype='object')

# %%
# Let's tackle these features: "Blue", "Wi_Fi", "Tch_Scr", "Ext_Mem"
import seaborn as sns
plt.figure(figsize=(12, 8))

features = ["Blue", "Wi_Fi", "Tch_Scr", "Ext_Mem"]
for i, feature in enumerate(features, 1):
    plt.subplot(2, 2, i)
    sns.countplot(x=feature, data=df, palette="pastel")
    plt.title(f"Distribution of {feature}")
    plt.xlabel(feature)
    plt.ylabel("Count")

plt.tight_layout()
plt.show()

# 2. Relationships with Price
print("Average Price based on Features:\n")
for feature in features:
    avg_price =df.groupby(feature)['Price'].mean()
    print(f"{feature}:\n{avg_price}\n")

# 3. Interdependencies Between Features
plt.figure(figsize=(10, 6))
sns.heatmap(df[features].apply(lambda x: x.map({'yes': 1, 'no': 0})).corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Between Features")
plt.show()
# Out:
# C:\Users\EKTA\AppData\Local\Temp\ipykernel_27864\2863266767.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette="pastel")
# C:\Users\EKTA\AppData\Local\Temp\ipykernel_27864\2863266767.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette="pastel")
# C:\Users\EKTA\AppData\Local\Temp\ipykernel_27864\2863266767.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette="pastel")
# C:\Users\EKTA\AppData\Local\Temp\ipykernel_27864\2863266767.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette="pastel")
# Average Price based on Features:
#
# Blue:
# Blue
# no     25596.304348
# yes    40778.814815
# Name: Price, dtype: float64
#
# Wi_Fi:
# Wi_Fi
# no     15705.000000
# yes    37240.547619
# Name: Price, dtype: float64
#
# Tch_Scr:
# Tch_Scr
# no      6657.000000
# yes    36810.177778
# Name: Price, dtype: float64
#
# Ext_Mem:
# Ext_Mem
# no     33779.166667
# yes    33799.815789
# Name: Price, dtype: float64

# %%
# The children want phones that have the following: Bluetooth, WiFi, touch screen and external memory support
# Create a logical condition for this situation and store the logical values as "con1"

con1 = (df['Blue'] == 'yes') & (df['Wi_Fi'] == 'yes') & (df['Tch_Scr'] == 'yes') & (df['Ext_Mem'] == 'yes')


df['con1'] = con1

# Display the counts of phones that meet the condition
print("Number of phones that meet the condition:")
df['con1'].value_counts()
# Out:
# Number of phones that meet the condition:
# con1
# False    31
# True     19
# Name: count, dtype: int64

# %% [markdown]
# Observations:
#
# The features "Blue", "Wi_Fi", "Tch_Scr" and "Ext_Mem" are binary in nature.
#
# The children want all these features, so the logical condition "con1" has been obtained accordingly.

# %% [markdown]
# ## Task 3 - Obtain the logical conditions for the features "Px_h" and "Px_w"

# %%
# Get the feature names of the dataframe

feature_names = df.columns
print("Feature names (column names):")
print(feature_names)
# Out:
# Feature names (column names):
# Index(['PID', 'Blue', 'Wi_Fi', 'Tch_Scr', 'Ext_Mem', 'Px_h', 'Px_w', 'Scr_h',
#        'Scr_w', 'PC', 'FC', 'Int_Mem', 'Bty_Pwr', 'RAM', 'Depth', 'Weight',
#        'Price', 'con1'],
#       dtype='object')

# %%
# Let's tackle these features: "Px_h", "Px_w"
features = ["Px_h", "Px_w"]

for feature in features:
    print(f"Feature: {feature}")
    print("Basic Statistics:")
    print(df[feature].describe())  
    print("\nUnique Values:")
    print(df[feature].unique())  
    print("-" * 30)
# Out:
# Feature: Px_h
# Basic Statistics:
# count      50.000000
# mean     2319.400000
# std       598.400623
# min       780.000000
# 25%      2080.000000
# 50%      2580.000000
# 75%      2580.000000
# max      2880.000000
# Name: Px_h, dtype: float64
#
# Unique Values:
# [ 780  840 1280 1390 2880 2580 2380 1980 1440 2440]
# ------------------------------
# Feature: Px_w
# Basic Statistics:
# count      50.000000
# mean     1833.200000
# std       469.713069
# min       460.000000
# 25%      1775.000000
# 50%      1980.000000
# 75%      2120.000000
# max      2520.000000
# Name: Px_w, dtype: float64
#
# Unique Values:
# [ 460  560  720 1120 1080 2120 1920 1980 1820 1760 1280 2520]
# ------------------------------

# %%
# Create a new feature called "Px" which stores the total resolution of the screen
df['Px'] = df['Px_h'] * df['Px_w']

# Display the first few rows to verify the new feature
print(df[['PID', 'Px_h', 'Px_w', 'Px']].head())
# Out:
#        PID  Px_h  Px_w       Px
# 0  AAB346A   780   460   358800
# 1  AAC347I   780   560   436800
# 2  BAB657J   840   720   604800
# 3  BBD456K  1280  1120  1433600
# 4  CCP761U  1280  1080  1382400

# %%
# Create a histogram of the "Px" feature and also show the mean and the median
px_mean = df['Px'].mean()
px_median = df['Px'].median()

# Create a histogram of the "Px" feature
plt.figure(figsize=(10, 6))
sns.histplot(df['Px'], kde=True, color='skyblue', bins=15, label='Px Distribution')

# Add vertical lines for mean and median
plt.axvline(px_mean, color='red', linestyle='--', label=f'Mean: {px_mean:.2f}')
plt.axvline(px_median, color='green', linestyle='--', label=f'Median: {px_median:.2f}')

# Customize the plot
plt.title('Histogram of Screen Resolution (Px)', fontsize=16)
plt.xlabel('Total Resolution (Px)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3)

# Show the plot
plt.show()

# %%
# The children want phones that have good screen resolutions
# Consider the phones that have screen resolutions greater than or equal to the median value in the data set
# Create a logical condition for this situation and store the logical values as "con2"
px_median = df['Px'].median()

# Create a logical condition for phones with resolutions >= median
con2 = df['Px'] >= px_median

# Store the logical values in a new column "con2"
df['con2'] = con2

# Display the counts of phones that meet the condition
print("Number of phones with resolutions >= median:")
df['con2'].value_counts()
# Out:
# Number of phones with resolutions >= median:
# con2
# True     30
# False    20
# Name: count, dtype: int64

# %% [markdown]
# Observations:
#
# The features "Px_h" and "Px_w" are respectively the number of pixels in the phone screen in the vertical and horizontal axes.
#
# We created a new feature called "Px" which is the product of the features "Px_h" and "Px_w".
#
# The median has been selected as a threshold in this case.
#
# In case it is too strict, we can choose the mean as a threshold.

# %% [markdown]
# # Task 4 - Obtain the logical conditions for the features "Scr_h" and "Scr_w"

# %%
# Let's tackle these features: "Scr_h", "Scr_w"
features = ["Scr_h", "Scr_w"]

for feature in features:
    print(f"Feature: {feature}")
    print("Basic Statistics:")
    print(df[feature].describe()) 
    print("\nUnique Values:")
    print(df[feature].unique())  
    print("-" * 30)
# Out:
# Feature: Scr_h
# Basic Statistics:
# count    50.000000
# mean      6.500000
# std       2.042907
# min       2.000000
# 25%       5.000000
# 50%       6.000000
# 75%       8.000000
# max      10.000000
# Name: Scr_h, dtype: float64
#
# Unique Values:
# [ 3  2  5  4  6  8 10]
# ------------------------------
# Feature: Scr_w
# Basic Statistics:
# count    50.000000
# mean      4.620000
# std       1.883223
# min       1.000000
# 25%       3.000000
# 50%       5.000000
# 75%       6.000000
# max       8.000000
# Name: Scr_w, dtype: float64
#
# Unique Values:
# [1 3 6 5 8 4]
# ------------------------------

# %%
# Create a new feature called "Scr_d" which stores the length of the diagonal of the screen of the phone

df['Scr_d'] = (df['Scr_h']**2 + df['Scr_w']**2)**0.5

# Display the first few rows to verify the new feature
print(df[['PID', 'Scr_h', 'Scr_w', 'Scr_d']].head())
# Out:
#        PID  Scr_h  Scr_w     Scr_d
# 0  AAB346A      3      1  3.162278
# 1  AAC347I      2      1  2.236068
# 2  BAB657J      2      1  2.236068
# 3  BBD456K      5      3  5.830952
# 4  CCP761U      4      3  5.000000

# %%
# Create a histogram of the "Scr_d" feature and also show the quartiles

scr_d_quartiles = df['Scr_d'].quantile([0.25, 0.5, 0.75])

# Create a histogram of the "Scr_d" feature
plt.figure(figsize=(10, 6))
sns.histplot(df['Scr_d'], kde=True, color='skyblue', bins=15, label='Scr_d Distribution')

# Add vertical lines for the quartiles
for q, value in scr_d_quartiles.items():
    plt.axvline(value, color='orange', linestyle='--', label=f'Q{int(q * 100)}: {value:.2f}')

# Customize the plot
plt.title('Histogram of Screen Diagonal Length (Scr_d)', fontsize=16)
plt.xlabel('Diagonal Length (Scr_d)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3)

# Show the plot
plt.show()

# Display quartiles
print("Quartiles of Scr_d:")
print(scr_d_quartiles)
# Out:
# Quartiles of Scr_d:
# 0.25     5.830952
# 0.50     7.810250
# 0.75    10.000000
# Name: Scr_d, dtype: float64

# %%
# The children want phones that have very good screen sizes
# Consider the phones that have screen sizes greater than or equal to the upper quartile value in the data set
# Create a logical condition for this situation and store the logical values as "con3"
scr_d_upper_quartile = df['Scr_d'].quantile(0.75)

# Create a logical condition for phones with screen sizes >= upper quartile
con3 = df['Scr_d'] >= scr_d_upper_quartile

# Store the logical values in a new column "con3"
df['con3'] = con3

# Display the counts of phones that meet the condition
print("Number of phones with screen sizes >= upper quartile:")
print(df['con3'].value_counts())
# Out:
# Number of phones with screen sizes >= upper quartile:
# con3
# False    26
# True     24
# Name: count, dtype: int64

# %% [markdown]
# Observations:
#
# The features "Scr_h" and "Scr_w" are respectively the height and the width of the phone screen.
#
# We created a new feature called "Scr_d" which is essentially the length of the screen diagonal.
#
# The upper quartile has been selected as a threshold in this case as the children were very particular on this point.
#
# In case it is too strict, we can choose the mean or the median as a threshold.

# %% [markdown]
# # Task 5 - Obtain the logical conditions for the features "PC" and "FC"

# %%
# Let's tackle these features: "PC", "FC"
features = ["PC", "FC"]

for feature in features:
    print(f"Feature: {feature}")
    print("Basic Statistics:")
    print(df[feature].describe()) 
    print("\nUnique Values:")
    print(df[feature].unique())  
    print("-" * 30)
# Out:
# Feature: PC
# Basic Statistics:
# count     50.000000
# mean      42.160000
# std       30.174567
# min        2.000000
# 25%       12.000000
# 50%       40.000000
# 75%       64.000000
# max      128.000000
# Name: PC, dtype: float64
#
# Unique Values:
# [  2   4   6   8  12  32  64  16  24  48 128]
# ------------------------------
# Feature: FC
# Basic Statistics:
# count    50.000000
# mean     20.760000
# std      14.784934
# min       2.000000
# 25%       8.000000
# 50%      16.000000
# 75%      32.000000
# max      64.000000
# Name: FC, dtype: float64
#
# Unique Values:
# [ 2  4  8 16 32 12 64]
# ------------------------------

# %%
# Create a histogram of the "PC" feature and also show the mean and the median


# Calculate the mean and median of the "PC" feature
pc_mean = df['PC'].mean()
pc_median = df['PC'].median()

# Create a histogram of the "PC" feature
plt.figure(figsize=(10, 6))
sns.histplot(df['PC'], kde=True, color='purple', bins=15, label='PC Distribution')

# Add vertical lines for mean and median
plt.axvline(pc_mean, color='red', linestyle='--', label=f'Mean: {pc_mean:.2f}')
plt.axvline(pc_median, color='green', linestyle='--', label=f'Median: {pc_median:.2f}')

# Customize the plot
plt.title('Histogram of Primary Camera Megapixels (PC)', fontsize=16)
plt.xlabel('Primary Camera (Megapixels)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3)

# Show the plot
plt.show()

# Print the mean and median
print(f"Mean of PC: {pc_mean:.2f}")
print(f"Median of PC: {pc_median:.2f}")
# Out:
# Mean of PC: 42.16
# Median of PC: 40.00

# %%
# Create a histogram of the "FC" feature and also show the mean and the median

fc_mean = df['FC'].mean()
fc_median = df['FC'].median()

# Create a histogram of the "FC" feature
plt.figure(figsize=(10, 6))
sns.histplot(df['FC'], kde=True, color='orange', bins=15, label='FC Distribution')

# Add vertical lines for mean and median
plt.axvline(fc_mean, color='red', linestyle='--', label=f'Mean: {fc_mean:.2f}')
plt.axvline(fc_median, color='green', linestyle='--', label=f'Median: {fc_median:.2f}')

# Customize the plot
plt.title('Histogram of Front Camera Megapixels (FC)', fontsize=16)
plt.xlabel('Front Camera (Megapixels)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3)

# Show the plot
plt.show()

# Print the mean and median
print(f"Mean of FC: {fc_mean:.2f}")
print(f"Median of FC: {fc_median:.2f}")
# Out:
# Mean of FC: 20.76
# Median of FC: 16.00

# %%
# The children want phones that have good primary and front camera resolutions
# Consider the phones that have primary and front camera resolutions greater than or equal to their respective mean values
# Create a logical condition for this situation and store the logical values as "con4"

# Calculate the mean values for PC (Primary Camera) and FC (Front Camera)
pc_mean = df['PC'].mean()
fc_mean = df['FC'].mean()

# Create a logical condition for phones meeting both criteria
con4 = (df['PC'] >= pc_mean) & (df['FC'] >= fc_mean)

# Store the logical values in a new column "con4"
df['con4'] = con4

# Display the counts of phones that meet the condition
print("Number of phones with good primary and front camera resolutions:")
print(df['con4'].value_counts())
# Out:
# Number of phones with good primary and front camera resolutions:
# con4
# False    28
# True     22
# Name: count, dtype: int64

# %% [markdown]
# Observations:
#
# The features "PC" and "FC" are respectively the resolutions of the primary camera and the front camera.
#
# The respective means have been selected as thresholds in this case.
#
# In case it is too strict, we can choose the respective medians as thresholds.

# %% [markdown]
# # Task 6 - Obtain the logical conditions for the features "Int_Mem", "Bty_Pwr" and "RAM"

# %%
# Let's tackle these features: "Int_Mem", "Bty_Pwr", "RAM"
features = ["Int_Mem", "Bty_Pwr", "RAM"]

for feature in features:
    print(f"Feature: {feature}")
    print("Basic Statistics:")
    print(df[feature].describe()) 
    print("\nUnique Values:")
    print(df[feature].unique())  
    print("-" * 30)
# Out:
# Feature: Int_Mem
# Basic Statistics:
# count      50.000000
# mean      173.760000
# std       261.771871
# min         8.000000
# 25%        32.000000
# 50%        64.000000
# 75%       128.000000
# max      1024.000000
# Name: Int_Mem, dtype: float64
#
# Unique Values:
# [   8   32   16   64  128  512  256 1024]
# ------------------------------
# Feature: Bty_Pwr
# Basic Statistics:
# count      50.000000
# mean     3740.000000
# std       958.817299
# min      2300.000000
# 25%      2800.000000
# 50%      3300.000000
# 75%      4500.000000
# max      5600.000000
# Name: Bty_Pwr, dtype: float64
#
# Unique Values:
# [2800 3000 3300 2980 3200 4380 4500 3900 4000 4400 4800 4300 4200 5000
#  4860 3400 5600 4560 2300]
# ------------------------------
# Feature: RAM
# Basic Statistics:
# count    50.000000
# mean      5.760000
# std       2.759473
# min       2.000000
# 25%       4.000000
# 50%       5.000000
# 75%       8.000000
# max      12.000000
# Name: RAM, dtype: float64
#
# Unique Values:
# [ 2  6  4  8 12]
# ------------------------------

# %%
# Create a histogram of the "Int_Mem" feature and also show the mean and the median


int_mem_mean = df['Int_Mem'].mean()
int_mem_median = df['Int_Mem'].median()

# Create a histogram of the "Int_Mem" feature
plt.figure(figsize=(10, 6))
sns.histplot(df['Int_Mem'], kde=True, color='blue', bins=15, label='Int_Mem Distribution')

# Add vertical lines for mean and median
plt.axvline(int_mem_mean, color='red', linestyle='--', label=f'Mean: {int_mem_mean:.2f}')
plt.axvline(int_mem_median, color='green', linestyle='--', label=f'Median: {int_mem_median:.2f}')

# Customize the plot
plt.title('Histogram of Internal Memory (Int_Mem)', fontsize=16)
plt.xlabel('Internal Memory (GB)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3)

# Show the plot
plt.show()

# Print the mean and median
print(f"Mean of Int_Mem: {int_mem_mean:.2f}")
print(f"Median of Int_Mem: {int_mem_median:.2f}")
# Out:
# Mean of Int_Mem: 173.76
# Median of Int_Mem: 64.00

# %%
# Create a histogram of the "Bty_Pwr" feature and also show the mean and the median

bty_pwr_mean = df['Bty_Pwr'].mean()
bty_pwr_median = df['Bty_Pwr'].median()

# Create a histogram of the "Bty_Pwr" feature
plt.figure(figsize=(10, 6))
sns.histplot(df['Bty_Pwr'], kde=True, color='teal', bins=15, label='Bty_Pwr Distribution')

# Add vertical lines for mean and median
plt.axvline(bty_pwr_mean, color='red', linestyle='--', label=f'Mean: {bty_pwr_mean:.2f}')
plt.axvline(bty_pwr_median, color='green', linestyle='--', label=f'Median: {bty_pwr_median:.2f}')

# Customize the plot
plt.title('Histogram of Battery Power (Bty_Pwr)', fontsize=16)
plt.xlabel('Battery Power (mAh)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3)

# Show the plot
plt.show()

# Print the mean and median
print(f"Mean of Bty_Pwr: {bty_pwr_mean:.2f}")
print(f"Median of Bty_Pwr: {bty_pwr_median:.2f}")
# Out:
# Mean of Bty_Pwr: 3740.00
# Median of Bty_Pwr: 3300.00

# %%
# Create a histogram of the "RAM" feature and also show the mean and the median

ram_mean = df['RAM'].mean()
ram_median = df['RAM'].median()

# Create a histogram of the "RAM" feature
plt.figure(figsize=(10, 6))
sns.histplot(df['RAM'], kde=True, color='blue', bins=15, label='RAM Distribution')

# Add vertical lines for mean and median
plt.axvline(ram_mean, color='red', linestyle='--', label=f'Mean: {ram_mean:.2f}')
plt.axvline(ram_median, color='green', linestyle='--', label=f'Median: {ram_median:.2f}')

# Customize the plot
plt.title('Histogram of RAM', fontsize=16)
plt.xlabel('RAM (MB)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3)

# Show the plot
plt.show()

# Print the mean and median
print(f"Mean of RAM: {ram_mean:.2f}")
print(f"Median of RAM: {ram_median:.2f}")
# Out:
# Mean of RAM: 5.76
# Median of RAM: 5.00

# %%
# The children want phones that have good internal memory, battery power and RAM
# Consider the phones that have internal memory, battery power and RAM greater than or equal to their respective mean values
# Create a logical condition for this situation and store the logical values as "con5"
# Create a logical condition for phones with good internal memory, battery power, and RAM
con5 = (
    (df['Int_Mem'] >= int_mem_mean) &  
    (df['Bty_Pwr'] >= bty_pwr_mean) & 
    (df['RAM'] >= ram_mean)           
)


df['con5'] = con5


print("Number of phones meeting the condition (con5):")
print(df['con5'].value_counts())
# Out:
# Number of phones meeting the condition (con5):
# con5
# False    41
# True      9
# Name: count, dtype: int64

# %% [markdown]
# Observations
#
# The features "Int_Mem", "Bty_Pwr" and "RAM" are respectively the internal memory, battery power and RAM of the phones.
#
# The respective means have been selected as thresholds in this case.
#
# .In case it is too strict, we can choose the respective medians as thresholds

# %% [markdown]
# # Task 7 - Obtain the logical conditions for the features "Depth" and "Weight"

# %%
# Let's tackle these features: "Depth", "Weight"
features = ["Depth", "Weight"]

for feature in features:
    print(f"Feature: {feature}")
    print("Basic Statistics:")
    print(df[feature].describe()) 
    print("\nUnique Values:")
    print(df[feature].unique())  
    print("-" * 30)
# Out:
# Feature: Depth
# Basic Statistics:
# count    50.000000
# mean      3.440000
# std       1.052887
# min       2.000000
# 25%       3.000000
# 50%       3.000000
# 75%       4.000000
# max       7.000000
# Name: Depth, dtype: float64
#
# Unique Values:
# [7 3 4 2]
# ------------------------------
# Feature: Weight
# Basic Statistics:
# count     50.000000
# mean     195.200000
# std       75.761171
# min       80.000000
# 25%      142.500000
# 50%      190.000000
# 75%      247.500000
# max      400.000000
# Name: Weight, dtype: float64
#
# Unique Values:
# [320 280 400 300 210 230 100  80 120 150 270 180 160 250 330 200 170 220
#   90 110 240 310 140 260 130]
# ------------------------------

# %%
# Create a histogram of the "Depth" feature and also show the mean and the median


depth_mean = df['Depth'].mean()
depth_median = df['Depth'].median()

# Create a histogram of the "Depth" feature
plt.figure(figsize=(10, 6))
sns.histplot(df['Depth'], kde=True, color='purple', bins=15, label='Depth Distribution')

# Add vertical lines for mean and median
plt.axvline(depth_mean, color='red', linestyle='--', label=f'Mean: {depth_mean:.2f}')
plt.axvline(depth_median, color='green', linestyle='--', label=f'Median: {depth_median:.2f}')

# Customize the plot
plt.title('Histogram of Depth', fontsize=16)
plt.xlabel('Depth (mm)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3)

# Show the plot
plt.show()

# Print the mean and median
print(f"Mean of Depth: {depth_mean:.2f}")
print(f"Median of Depth: {depth_median:.2f}")
# Out:
# Mean of Depth: 3.44
# Median of Depth: 3.00

# %%
# Create a histogram of the "Weight" feature and also show the mean and the median

weight_mean = df['Weight'].mean()
weight_median = df['Weight'].median()

# Create a histogram of the "Weight" feature
plt.figure(figsize=(10, 6))
sns.histplot(df['Weight'], kde=True, color='orange', bins=15, label='Weight Distribution')

# Add vertical lines for mean and median
plt.axvline(weight_mean, color='red', linestyle='--', label=f'Mean: {weight_mean:.2f}')
plt.axvline(weight_median, color='green', linestyle='--', label=f'Median: {weight_median:.2f}')

# Customize the plot
plt.title('Histogram of Weight', fontsize=16)
plt.xlabel('Weight (grams)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.legend()
plt.grid(True, alpha=0.3)

# Show the plot
plt.show()

# Print the mean and median
print(f"Mean of Weight: {weight_mean:.2f}")
print(f"Median of Weight: {weight_median:.2f}")
# Out:
# Mean of Weight: 195.20
# Median of Weight: 190.00

# %%
# The children want phones that are light weight and slim
# Consider the phones that have depth and weight less than or equal to the respective median values in the data set
# Create a logical condition for this situation and store the logical values as "con6"

# Calculate the median values for Depth and Weight
depth_median = df['Depth'].median()
weight_median = df['Weight'].median()

# Create the logical condition for lightweight and slim phones
df['con6'] = (df['Depth'] <= depth_median) & (df['Weight'] <= weight_median)

# Display a summary of the new logical condition
print("Summary of 'con6' Logical Condition:")
print(df['con6'].value_counts())
print("\nSample Data with 'con6':")
print(df[['Depth', 'Weight', 'con6']].head())
# Out:
# Summary of 'con6' Logical Condition:
# con6
# False    31
# True     19
# Name: count, dtype: int64
#
# Sample Data with 'con6':
#    Depth  Weight   con6
# 0      7     320  False
# 1      7     280  False
# 2      7     400  False
# 3      3     300  False
# 4      3     210  False

# %% [markdown]
# Observations:
#
# The features "Depth" and "Weight" are respectively the depth of the phone and the weight of the phone.
#
# The respective medians have been selected as thresholds in this case.
#
# In case it is too strict, we can choose the respective means as thresholds.

# %% [markdown]
# # Task 8 - Subset the data based on all the logical conditions

# %%
# Subset the dataframe using all the logical conditions that have been stored
# Store the subset of the dataframe as a new dataframe called "df1"

df1 = df[
    df['con1'] & 
    df['con2'] &
    df['con3'] & 
    df['con4'] &  
    df['con5'] &  
    df['con6'] 
]

# Display the subset dataframe and its dimensions
print("Subset DataFrame 'df1' Info:")
print(df1.info())

print("\nSample Data from 'df1':")
print(df1.head())

print(f"\nDimensions of 'df1': {df1.shape}")
# Out:
# Subset DataFrame 'df1' Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 30 to 42
# Data columns (total 25 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PID      3 non-null      object
#  1   Blue     3 non-null      object
#  2   Wi_Fi    3 non-null      object
#  3   Tch_Scr  3 non-null      object
#  4   Ext_Mem  3 non-null      object
#  5   Px_h     3 non-null      int64
#  6   Px_w     3 non-null      int64
#  7   Scr_h    3 non-null      int64
#  8   Scr_w    3 non-null      int64
#  9   PC       3 non-null      int64
#  10  FC       3 non-null      int64
#  11  Int_Mem  3 non-null      int64
#  12  Bty_Pwr  3 non-null      int64
#  13  RAM      3 non-null      int64
#  14  Depth    3 non-null      int64
#  15  Weight   3 non-null      int64
#  16  Price    3 non-null      int64
#  17  con1     3 non-null      bool
#  18  Px       3 non-null      int64
#  19  con2     3 non-null      bool
#  20  Scr_d    3 non-null      float64
#  21  con3     3 non-null      bool
#  22  con4     3 non-null      bool
#  23  con5     3 non-null      bool
#  24  con6     3 non-null      bool
# dtypes: bool(6), float64(1), int64(13), object(5)
# memory usage: 498.0+ bytes
# None
#
# Sample Data from 'df1':
#         PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  ...  \
# 30  TVF078Y  yes   yes     yes     yes  2580  2120      8      6  64  ...
# 32  TYS938L  yes   yes     yes     yes  2580  2120      8      6  64  ...
# 42  WZB298K  yes   yes     yes     yes  2580  1980      8      6  64  ...
#
#     Weight  Price  con1       Px  con2  Scr_d  con3  con4  con5  con6
# 30      90  29999  True  5469600  True   10.0  True  True  True  True
# 32     120  46777  True  5469600  True   10.0  True  True  True  True
# 42     160  39000  True  5108400  True   10.0  True  True  True  True
#
# [3 rows x 25 columns]
#
# Dimensions of 'df1': (3, 25)

# %%
# Get the dimensions of the dataframe

df1.shape
# Out:
# (3, 25)

# %%
# Sort the dataframe according to the "Price" feature in ascending order and display it

df1_sorted = df1.sort_values(by='Price', ascending=True)

# Display the sorted dataframe
print("Subset DataFrame sorted by 'Price' (ascending):")
print(df1_sorted)
# Out:
# Subset DataFrame sorted by 'Price' (ascending):
#         PID Blue Wi_Fi Tch_Scr Ext_Mem  Px_h  Px_w  Scr_h  Scr_w  PC  ...  \
# 30  TVF078Y  yes   yes     yes     yes  2580  2120      8      6  64  ...
# 42  WZB298K  yes   yes     yes     yes  2580  1980      8      6  64  ...
# 32  TYS938L  yes   yes     yes     yes  2580  2120      8      6  64  ...
#
#     Weight  Price  con1       Px  con2  Scr_d  con3  con4  con5  con6
# 30      90  29999  True  5469600  True   10.0  True  True  True  True
# 42     160  39000  True  5108400  True   10.0  True  True  True  True
# 32     120  46777  True  5469600  True   10.0  True  True  True  True
#
# [3 rows x 25 columns]

# %% [markdown]
# Observations:
#
# Based on all the logical conditions obtained through analysis of the features, we are left with three phones.
#
# The most expensive of these phones is the "TYS938L" model and the least expensive is the "TVF078Y" model.
#
# We could let the children choose from these three phones as per their preferences.

# %% [markdown]
# # Task 9 - Study the variability of the features in the original data set

# %%
# Calculate the ratio of the standard deviation to the mean for all the numerical features in the dataframe
# Store these values in a new series wherein the rows are the features and the only column is the calculated ratio
# Name the series as "deviations"

# Calculate the ratio of standard deviation to mean for all numerical features
numerical_features = df1.select_dtypes(include=['number'])  # Select only numerical columns
deviations = numerical_features.std() / numerical_features.mean()  # Standard deviation to mean ratio

# Store these values in a new series
deviations = deviations.rename("deviations")

# Display the series
print("Standard Deviation to Mean Ratios:")
print(deviations)
# Out:
# Standard Deviation to Mean Ratios:
# Px_h       0.000000
# Px_w       0.038985
# Scr_h      0.000000
# Scr_w      0.000000
# PC         0.000000
# FC         0.000000
# Int_Mem    0.346410
# Bty_Pwr    0.083663
# RAM        0.000000
# Depth      0.000000
# Weight     0.284747
# Price      0.217569
# Px         0.038985
# Scr_d      0.000000
# Name: deviations, dtype: float64

# %%
# View the "deviations" series after sorting it in descending order

# Sort the "deviations" series in descending order
deviations_sorted = deviations.sort_values(ascending=False)

# Display the sorted series
print("Sorted 'deviations' Series (Descending Order):")
print(deviations_sorted)
# Out:
# Sorted 'deviations' Series (Descending Order):
# Int_Mem    0.346410
# Weight     0.284747
# Price      0.217569
# Bty_Pwr    0.083663
# Px_w       0.038985
# Px         0.038985
# Px_h       0.000000
# Scr_h      0.000000
# Scr_w      0.000000
# PC         0.000000
# FC         0.000000
# RAM        0.000000
# Depth      0.000000
# Scr_d      0.000000
# Name: deviations, dtype: float64

# %% [markdown]
# Observations:
#
# The ratio of the standard deviation to the mean of a feature normalises it in a way.
#
# This allows for comparison between multiple features.
#
# The most variable feature in the original data set is the internal memory of the phones.
#
# The least variable feature in the original data set is the number of screen pixels in the horizontal axis.
#
# Although most features don't seem so variable, the prices of the phones are quite variable.
#
# Feel free to investigate what could be the cause of this difference in variability.
#
# Note: We encourage you to extend this analysis further and see what else you can find.
#
# Note: Please refer to the official website of Python and its libraries for various Python documentations.

# %% [markdown]
# # Conclusion
# 1. We have used concepts of descriptive statistics to study and work with a data set that contains mobile phone specifications.
#
# 2. We were able to recommend three phone models to the client which she can then propose to her children.
